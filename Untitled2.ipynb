# %% [markdown]
# <a href="https://colab.research.google.com/github/ChaithraRamesh/auth-repo/blob/master/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
fptr=open("airlines.csv","r")
data=fptr.readlines()
for a in data:
     wordlist=a.split()
     for word in wordlist:
       word1=word.split()
       print(word1)
# Out:
# Streaming output truncated to the last 5000 lines.
# ['MA:']
# ['Logan']
# ['International",2013,479']
# ['BWI,"Baltimore,']
# ['MD:']
# ['Baltimore/Washington']
# ['International']
# ['Thurgood']
# ['Marshall",2013,155']
# ['CLT,"Charlotte,']
# ['NC:']
# ['Charlotte']
# ['Douglas']
# ['International",2013,196']
# ['DCA,"Washington,']
# ['DC:']
# ['Ronald']
# ['Reagan']
# ['Washington']
# ['National",2013,203']
# ['DEN,"Denver,']
# ['CO:']
# ['Denver']
# ['International",2013,486']
# ['DFW,"Dallas/Fort']
# ['Worth,']
# ['TX:']
# ['Dallas/Fort']
# ['Worth']
# ['International",2013,409']
# ['DTW,"Detroit,']
# ['MI:']
# ['Detroit']
# ['Metro']
# ['Wayne']
# ['County",2013,284']
# ['EWR,"Newark,']
# ['NJ:']
# ['Newark']
# ['Liberty']
# ['International",2013,538']
# ['FLL,"Fort']
# ['Lauderdale,']
# ['FL:']
# ['Fort']
# ['Lauderdale-Hollywood']
# ['International",2013,95']
# ['IAD,"Washington,']
# ['DC:']
# ['Washington']
# ['Dulles']
# ['International",2013,154']
# ['IAH,"Houston,']
# ...

# %%
fptr=open("airlines.csv","r")
data=fptr.readlines()
word2=' '
for a in data:
     wordlist=a.split()
     
     for word in wordlist:
       word2=word2+word[1:8]
     print(word2)
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
